# %%
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import boto3
import sagemaker
from sagemaker import get_execution_role

np.random.seed(1)

# %%
prefix = "sagemaker/DEMO-deepar"

sagemaker_session = sagemaker.Session()
role = get_execution_role()
bucket = sagemaker_session.default_bucket()

s3_data_path = f"{bucket}/{prefix}/data"
s3_output_path = f"{bucket}/{prefix}/output"
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# /tmp/ipykernel_6621/3947877595.py in <module>
#       2
#       3 sagemaker_session = sagemaker.Session()
# ----> 4 role = get_execution_role()
#       5 bucket = sagemaker_session.default_bucket()
#       6
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/sagemaker/session.py in get_execution_role(sagemaker_session)
#    4367     if not sagemaker_session:
#    4368         sagemaker_session = Session()
# -> 4369     arn = sagemaker_session.get_caller_identity_arn()
#    4370
#    4371     if ":role/" in arn:
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/sagemaker/session.py in get_caller_identity_arn(self)
#    3570                 )
#    3571
# -> 3572         assumed_role = self.boto_session.client(
#    3573             "sts",
#    3574             region_name=self.boto_region_name,
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     386                     "%s() only accepts keyword arguments." % py_operation_name)
#     387             # The "self" in this scope is referring to the BaseClient.
# --> 388             return self._make_api_call(operation_name, kwargs)
#     389
#     390         _api_call.__name__ = str(py_operation_name)
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     692             http, parsed_response = event_response
#     693         else:
# --> 694             http, parsed_response = self._make_request(
#     695                 operation_model, request_dict, request_context)
#     696
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     712     def _make_request(self, operation_model, request_dict, request_context):
#     713         try:
# --> 714             return self._endpoint.make_request(operation_model, request_dict)
#     715         except Exception as e:
#     716             self.meta.events.emit(
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     130     def _send_request(self, request_dict, operation_model):
#     131         attempts = 1
# --> 132         request = self.create_request(request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/endpoint.py in create_request(self, params, operation_model)
#     113                 service_id=service_id,
#     114                 op_name=operation_model.name)
# --> 115             self._event_emitter.emit(event_name, request=request,
#     116                                      operation_name=operation_model.name)
#     117         prepared_request = self.prepare_request(request)
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     355     def emit(self, event_name, **kwargs):
#     356         aliased_event_name = self._alias_event_name(event_name)
# --> 357         return self._emitter.emit(aliased_event_name, **kwargs)
#     358
#     359     def emit_until_response(self, event_name, **kwargs):
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     226                  handlers.
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#     230     def emit_until_response(self, event_name, **kwargs):
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     209         for handler in handlers_to_call:
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#     213             if stop_on_response and response is not None:
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/signers.py in handler(self, operation_name, request, **kwargs)
#      91         # this method is invoked to sign the request.
#      92         # Don't call this method directly.
# ---> 93         return self.sign(operation_name, request)
#      94
#      95     def sign(self, operation_name, request, region_name=None,
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/signers.py in sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     163                     raise e
#     164
# --> 165             auth.add_auth(request)
#     166
#     167     def _choose_signer(self, operation_name, signing_type, context):
#
# ~/git/pier-11/glomimo/venv/lib/python3.9/site-packages/botocore/auth.py in add_auth(self, request)
#     376     def add_auth(self, request):
#     377         if self.credentials is None:
# --> 378             raise NoCredentialsError()
#     379         datetime_now = datetime.datetime.utcnow()
#     380         request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
freq = "D"
prediction_length = 365
context_length = 730
